# %% [markdown]
# # Instalasi **TensorFlow** dan **TensorFlowjs**

# %%
# Instalasi tensorFlow
# !pip show tensorflow > /dev/null || pip install tensorflow --quiet
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.17.1
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, keras, libclang, ml-dtypes, numpy, opt-einsum, packaging, protobuf, requests, setuptools, six, tensorboard, tensorflow-io-gcs-filesystem, termcolor, typing-extensions, wrapt
# Required-by: dopamine_rl, tf_keras

# %%
# Instalasi tensorFlowjs
# !pip show tensorflowjs > /dev/null || pip install tensorflowjs --quiet
# !pip show tensorflowjs
# Out:
# WARNING: Package(s) not found: tensorflowjs
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 51.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.3/615.3 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 68.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 96.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 102.7 MB/s eta 0:00:00
# Name: tensorflowjs
# Version: 4.22.0
# Summary:
# Home-page: https://js.tensorflow.org/
# Author: Google LLC
# Author-email: opensource@google.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: flax, importlib_resources, jax, jaxlib, packaging, six, tensorflow, tensorflow-decision-forests, tensorflow-hub, tf-keras
# Required-by:

# %% [markdown]
# # Import Library

# %%
# Mingimpor Pustaka
from google.colab import drive

import os
import numpy as np

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

import zipfile
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Dataset

# %%
# Mengatur lokasi path file yang dipakai di google drive
drive.mount('/content/drive', force_remount = True)
os.chdir('/content/drive/Shareddrives')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/Shareddrives/BANGKIT/garbage_classification /content/dataset/

# %%
# Menyimpan lokasi direktori dataset di Google Drive
dataset_path = '/content/dataset'

# %% [markdown]
# # Preprocessing Data

# %%
# Memuat dataset gambar 'sampah' dari google drive
# Membagi dataset gambar 'sampah' menjadi data training dan validasi
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2, # memisahkan 20% data untuk validasi
    subset="training",
    seed=123,
    image_size=(224, 224), # menetapkan ukuran gambar yang konsisten
    batch_size=32
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2, # memisahkan 20% data untuk validasi
    subset="validation",
    seed=123,
    image_size=(224, 224), # menetapkan ukuran gambar yang konsisten
    batch_size=32
)

class_names = train_ds.class_names
num_classes = len(class_names)
# Out:
# Found 15513 files belonging to 12 classes.
# Using 12411 files for training.
# Found 15513 files belonging to 12 classes.
# Using 3102 files for validation.

# %% [markdown]
# ### Melihat Total Data Train Setiap Classes

# %%
class_counts = {label: 0 for label in class_names}
for _, labels in train_ds:
    for label in labels.numpy():
        class_counts[class_names[label]] += 1
print(class_counts)
# Out:
# {'battery': 758, 'biological': 785, 'brown-glass': 474, 'cardboard': 713, 'clothes': 4255, 'green-glass': 514, 'metal': 601, 'paper': 852, 'plastic': 681, 'shoes': 1583, 'trash': 567, 'white-glass': 628}

# %% [markdown]
# ### Normalisasi Data

# %%
# menghindari nilai piksel yang besar
normalization_layer = layers.Rescaling(1./255)

# %% [markdown]
# ### Augmentasi Data

# %%
# Melakukan augmentasi data pada dataset training
# Menerapkan normalisasi pada dataset training dan validasi.
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])

train_ds = train_ds.map(lambda x, y: (data_augmentation(normalization_layer(x)), y))
val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))

# %% [markdown]
# ### Optimasi dengan Prefetching, caching, shuffling

# %%
# Meningkatkan efisiensi pemrosesan data menggunakan caching, shuffling, dan prefetching
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

for image_batch, labels_batch in train_ds.take(1):
  print("Image batch shape: ", image_batch.shape)
  print("Label batch shape: ", labels_batch.shape)
# Out:
# Image batch shape:  (32, 224, 224, 3)
# Label batch shape:  (32,)

# %% [markdown]
# # Visualisasi Data
#
#   Run kembali untuk melihat output yang lain

# %%
# Menampilkan contoh gambar dari batch data training
for image_batch, label_batch in train_ds.take(1):
  plt.figure(figure=(10, 10))
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy())
    plt.title(int(label_batch[i]))
    plt.axis("off")
  plt.show()

# %% [markdown]
# # Create dan Compile Model

# %%
# Menampilkan jumlah GPU yang tersedia
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Path ke dataset
dataset_path = '/content/dataset'

# Inisialisasi Dataset Training dan Validasi
train_ds = image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(224, 224),
    batch_size=32
)

val_ds = image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(224, 224),
    batch_size=32
)

# Menentukan Jumlah Kelas
num_classes = len(train_ds.class_names)

# Mendefinisikan Model CNN
def create_model():
    inputs = layers.Input(shape=(224, 224, 3))
    base_model = ResNet50(include_top=False, weights='imagenet', input_tensor=inputs)
    base_model.trainable = False

    x = base_model(inputs)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(512, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs=inputs, outputs=outputs)

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    return model

model = create_model()
model.summary()
# Out:
# Num GPUs Available:  1
# Found 15513 files belonging to 12 classes.
# Using 12411 files for training.
# Found 15513 files belonging to 12 classes.
# Using 3102 files for validation.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ resnet50 (Functional)                │ (None, 7, 7, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 2048)                │           8,192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       1,049,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 12)                  │           6,156 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 24,651,148 (94.04 MB)
#  Trainable params: 1,059,340 (4.04 MB)
#  Non-trainable params: 23,591,808 (90.00 MB)

# %% [markdown]
# # Train Model

# %%
# Menampilkan model
model = create_model()

# Aktifkan fine-tuning
base_model = model.layers[1]
base_model.trainable = True
for layer in base_model.layers[:-50]:
    layer.trainable = False

# Re-compile model
optimizer = tf.keras.optimizers.SGD(learning_rate=0.0001, momentum=0.9)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Menentukan Callback
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ModelCheckpoint('/content/best_model.keras', save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-7)
]

# Menentukan Parameter Pelatihan
num_train_samples = 12412
num_val_samples = 3103

batch_size = 32
steps_per_epoch = num_train_samples // batch_size
validation_steps = num_val_samples // batch_size

train_ds = train_ds.repeat()
val_ds = val_ds.repeat()

# Melatih model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    epochs=20,
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 90s 165ms/step - accuracy: 0.3914 - loss: 2.2534 - val_accuracy: 0.8421 - val_loss: 0.5220 - learning_rate: 1.0000e-04
# Epoch 2/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 78s 171ms/step - accuracy: 0.8063 - loss: 0.6183 - val_accuracy: 0.8840 - val_loss: 0.3671 - learning_rate: 1.0000e-04
# Epoch 3/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 63s 162ms/step - accuracy: 0.8651 - loss: 0.4308 - val_accuracy: 0.9023 - val_loss: 0.2989 - learning_rate: 1.0000e-04
# Epoch 4/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 62s 161ms/step - accuracy: 0.8938 - loss: 0.3352 - val_accuracy: 0.9094 - val_loss: 0.2691 - learning_rate: 1.0000e-04
# Epoch 5/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 62s 161ms/step - accuracy: 0.9105 - loss: 0.2762 - val_accuracy: 0.9215 - val_loss: 0.2415 - learning_rate: 1.0000e-04
# Epoch 6/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 63s 162ms/step - accuracy: 0.9281 - loss: 0.2341 - val_accuracy: 0.9238 - val_loss: 0.2319 - learning_rate: 1.0000e-04
# Epoch 7/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 62s 161ms/step - accuracy: 0.9416 - loss: 0.1884 - val_accuracy: 0.9300 - val_loss: 0.2139 - learning_rate: 1.0000e-04
# Epoch 8/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 62s 161ms/step - accuracy: 0.9492 - loss: 0.1580 - val_accuracy: 0.9326 - val_loss: 0.2069 - learning_rate: 1.0000e-04
# Epoch 9/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 62s 161ms/step - accuracy: 0.9522 - loss: 0.1467 - val_accuracy: 0.9358 - val_loss: 0.1979 - learning_rate: 1.0000e-04
# Epoch 10/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 62s 161ms/step - accuracy: 0.9602 - loss: 0.1261 - val_accuracy: 0.9397 - val_loss: 0.1896 - learning_rate: 1.0000e-04
# Epoch 11/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 62s 160ms/step - accuracy: 0.9668 - loss: 0.1087 - val_accuracy: 0.9423 - val_loss: 0.1869 - learning_rate: 1.0000e-04
# Epoch 12/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 62s 161ms/step - accuracy: 0.9705 - loss: 0.0972 - val_accuracy: 0.9430 - val_loss: 0.1792 - learning_rate: 1.0000e-04
# Epoch 13/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 61s 158ms/step - accuracy: 0.9768 - loss: 0.0819 - val_accuracy: 0.9469 - val_loss: 0.1843 - learning_rate: 1.0000e-04
# Epoch 14/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 62s 161ms/step - accuracy: 0.9743 - loss: 0.0855 - val_accuracy: 0.9440 - val_loss: 0.1785 - learning_rate: 1.0000e-04
# Epoch 15/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 61s 158ms/step - accuracy: 0.9772 - loss: 0.0768 - val_accuracy: 0.9476 - val_loss: 0.1795 - learning_rate: 1.0000e-04
# Epoch 16/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 63s 162ms/step - accuracy: 0.9805 - loss: 0.0674 - val_accuracy: 0.9463 - val_loss: 0.1752 - learning_rate: 1.0000e-04
# Epoch 17/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 61s 158ms/step - accuracy: 0.9853 - loss: 0.0567 - val_accuracy: 0.9469 - val_loss: 0.1778 - learning_rate: 1.0000e-04
# Epoch 18/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 62s 161ms/step - accuracy: 0.9862 - loss: 0.0489 - val_accuracy: 0.9495 - val_loss: 0.1727 - learning_rate: 1.0000e-04
# Epoch 19/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 61s 157ms/step - accuracy: 0.9868 - loss: 0.0476 - val_accuracy: 0.9472 - val_loss: 0.1811 - learning_rate: 1.0000e-04
# Epoch 20/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 61s 157ms/step - accuracy: 0.9898 - loss: 0.0429 - val_accuracy: 0.9492 - val_loss: 0.1785 - learning_rate: 1.0000e-04

# %%
# Cetak Akurasi Model
test_loss, test_acc = model.evaluate(val_ds, steps=5000)
print(f"Test accuracy: {test_acc}")
# Out:
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 436s 87ms/step - accuracy: 0.9478 - loss: 0.1765
# Test accuracy: 0.9477604627609253

# %% [markdown]
# # Grafik Akurasi Training dan Validasi

# %%
# Memuat data training dan validasi
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# memuat jumlah epoch
epochs = range(len(acc))

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
fig.suptitle('Training and validation accuracy')

for i, (data, label) in enumerate(zip([(acc, val_acc), (loss, val_loss)], ["Accuracy", "Loss"])):
    ax[i].plot(epochs, data[0], 'r', label="Training " + label)
    ax[i].plot(epochs, data[1], 'b', label="Validation " + label)
    ax[i].legend()
    ax[i].set_xlabel('epochs')

plt.show()

# %% [markdown]
# # Save Model ke dalam **TensorFlowjs**

# %%
from tensorflow.keras.models import load_model

model = load_model('/content/best_model.keras')
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ resnet50 (Functional)                │ (None, 7, 7, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 2048)                │           8,192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 512)                 │       1,049,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 12)                  │           6,156 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 42,661,018 (162.74 MB)
#  Trainable params: 18,009,868 (68.70 MB)
#  Non-trainable params: 6,641,280 (25.33 MB)
#  Optimizer params: 18,009,870 (68.70 MB)

# %%
model.export('/content/best_model')
# Out:
# Saved artifact at '/content/best_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_2')
# Output Type:
#   TensorSpec(shape=(None, 12), dtype=tf.float32, name=None)
# Captures:
#   138009940718544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009940740048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009940748144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009940750256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009940743568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009940745856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009940744800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009940805584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009940804704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009940810688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009940808400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009940806992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009940813328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009940814208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009940805760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009940818432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009940816144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009940814736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938791408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938791584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009940817728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938788416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938788592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938796160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938793872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938790528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938792816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938799856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938797568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938798624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938799152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938857472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938856592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938858352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938856240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938854656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938860992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938861872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938856768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938866096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938863808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938862400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938869616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938865392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938937808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938939568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938937456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938935872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938943616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938944496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938940800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938948720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938946432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938945024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938948016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939021312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939020432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939022192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939020080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939018496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939024832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939025712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138010755230432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138010555880320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939027648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939026240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138012879414624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939026592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939030640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939031696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939029584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939028000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939030992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939149216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939149568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939154320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939152032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939150624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939159952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939160128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939156960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939157840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939150272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939164704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939162416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939159072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939230960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939234128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939231840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939232896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939238176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939239056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939235360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939243280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939240992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939239584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939246800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939245920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939298608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939300368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939298256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939296672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939303008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939303888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939298784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939308112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939305824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939304416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939307408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939382112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939378240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939382992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939380880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939379296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939385632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939386512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939380176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939390736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939388448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939387040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939394256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939393376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939462448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939464208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939462096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939460512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939468256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939469136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939465440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939473360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939471072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939469664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939472656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939562336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939558464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939563216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939561104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939559520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939565856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939566736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939560400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939570960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939568672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939567264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939570256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939640736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939641088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939645840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939643552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939642144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939648480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939649360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939641792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939653584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939651296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939649888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939707504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939709440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939652880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939709792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939712256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939713312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939711024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939709088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939711200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939717008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939714720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939715776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939721936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009939721056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937725744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937727504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937725392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937723808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937730144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937731024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937725920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937735248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937732960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937731552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937738768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937739472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937807664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937808720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937805552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937806784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937812768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937813648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937809952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937817872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937815584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937814176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937821392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937820512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937889584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937891344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937889232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937887648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937893984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937894864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937889760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937899088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937896800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937895392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009937898384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938005856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938001984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938006736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938004624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938003040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938009376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938010256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938003920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938014480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938012192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938010784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938018000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938017120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938069808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938071568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938069456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938067872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938075616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938076496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938072800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938080720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938078432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938077024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938080016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938153312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938149440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938154192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938152080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938150496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938156832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938157712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938151376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938161936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938159648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938158240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938161232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938248096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938248448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938253200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938250912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938249504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938255840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938256720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938249152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938260944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938258656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938257248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938260240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938349920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938346048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938350800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938348688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938347104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938354848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938355728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938352032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938359952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938357664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938356256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938359248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938444704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938445056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938449808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938447520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938446112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938455440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938455616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938452448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938453328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938445760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938460192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938457904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938454560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938526448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938529616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938527328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938528384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938533664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938534544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938530848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938538768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938536480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938535072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938542288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938541408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938594096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938595856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938593744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938592160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938598496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938599376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938594272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938603600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938601312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938599904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938602896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938693984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938690112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938694864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938692752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938691168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938697504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938698384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938692048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938702608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938700320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938698912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938706128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009938705248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009936677168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009936678928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009936676816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009936675232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009936939840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009936943712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009936941424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009936942480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009936946352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009936945824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009936950576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138009936950224: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
# !tensorflowjs_converter --input_format=tf_saved_model --saved_model_tags=serve /content/best_model /content/model
# Out:
# 2024-12-04 18:18:57.939461: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733336337.966366   30804 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733336337.975969   30804 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 🌲 Try https://ydf.readthedocs.io, the successor of TensorFlow Decision Forests with more features and faster training!
# 2024-12-04 18:19:06.689231: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1733336346.689415   30804 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5609 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1733336348.770940   30804 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733336348.771167   30804 single_machine.cc:361] Starting new session
# I0000 00:00:1733336348.772263   30804 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5609 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5

# %%
# !zip -r /content/model.zip /content/model
# Out:
#   adding: content/model/ (stored 0%)
#   adding: content/model/model.json (deflated 96%)
#   adding: content/model/group1-shard22of24.bin (deflated 7%)
#   adding: content/model/group1-shard24of24.bin (deflated 8%)
#   adding: content/model/group1-shard18of24.bin (deflated 7%)
#   adding: content/model/group1-shard17of24.bin (deflated 7%)
#   adding: content/model/group1-shard3of24.bin (deflated 7%)
#   adding: content/model/group1-shard21of24.bin (deflated 7%)
#   adding: content/model/group1-shard19of24.bin (deflated 7%)
#   adding: content/model/group1-shard14of24.bin (deflated 7%)
#   adding: content/model/group1-shard2of24.bin (deflated 7%)
#   adding: content/model/group1-shard23of24.bin (deflated 7%)
#   adding: content/model/group1-shard7of24.bin (deflated 7%)
#   adding: content/model/group1-shard5of24.bin (deflated 7%)
#   adding: content/model/group1-shard6of24.bin (deflated 7%)
#   adding: content/model/group1-shard16of24.bin (deflated 7%)
#   adding: content/model/group1-shard1of24.bin (deflated 7%)
#   adding: content/model/group1-shard13of24.bin (deflated 7%)
#   adding: content/model/group1-shard20of24.bin (deflated 7%)
#   adding: content/model/group1-shard4of24.bin (deflated 7%)
#   adding: content/model/group1-shard11of24.bin (deflated 7%)
#   adding: content/model/group1-shard15of24.bin (deflated 7%)
#   adding: content/model/group1-shard9of24.bin (deflated 7%)
#   adding: content/model/group1-shard10of24.bin (deflated 7%)
#   adding: content/model/group1-shard12of24.bin (deflated 7%)
#   adding: content/model/group1-shard8of24.bin (deflated 7%)

# %%
from google.colab import files
files.download('/content/model.zip')
