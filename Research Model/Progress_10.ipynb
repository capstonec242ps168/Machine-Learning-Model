# %% [markdown]
# # Instalasi **TensorFlow** dan **TensorFlowjs**

# %%
# Instalasi tensorFlow
# !pip show tensorflow > /dev/null || pip install tensorflow --quiet
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.17.1
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, keras, libclang, ml-dtypes, numpy, opt-einsum, packaging, protobuf, requests, setuptools, six, tensorboard, tensorflow-io-gcs-filesystem, termcolor, typing-extensions, wrapt
# Required-by: dopamine_rl, tf_keras

# %%
# Instalasi tensorFlowjs
# !pip show tensorflowjs > /dev/null || pip install tensorflowjs --quiet
# !pip show tensorflowjs
# Out:
# WARNING: Package(s) not found: tensorflowjs
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 66.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.3/615.3 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 72.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 102.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 111.2 MB/s eta 0:00:00
# Name: tensorflowjs
# Version: 4.22.0
# Summary:
# Home-page: https://js.tensorflow.org/
# Author: Google LLC
# Author-email: opensource@google.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: flax, importlib_resources, jax, jaxlib, packaging, six, tensorflow, tensorflow-decision-forests, tensorflow-hub, tf-keras
# Required-by:

# %% [markdown]
# # Import Library

# %%
# Mingimpor Pustaka
from google.colab import drive

import os
import numpy as np

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

import zipfile
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Dataset

# %%
# Mengatur lokasi path file yang dipakai di google drive
drive.mount('/content/drive', force_remount = True)
os.chdir('/content/drive/Shareddrives')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/Shareddrives/BANGKIT/garbage_classification /content/dataset/

# %%
# Menyimpan lokasi direktori dataset di Google Drive
dataset_path = '/content/dataset'

# %% [markdown]
# # Preprocessing Data

# %%
# Memuat dataset gambar 'sampah' dari google drive
# Membagi dataset gambar 'sampah' menjadi data training dan validasi
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2, # memisahkan 20% data untuk validasi
    subset="training",
    seed=123,
    image_size=(128, 128), # menetapkan ukuran gambar yang konsisten
    batch_size=32
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2, # memisahkan 20% data untuk validasi
    subset="validation",
    seed=123,
    image_size=(128, 128), # menetapkan ukuran gambar yang konsisten
    batch_size=32
)

class_names = train_ds.class_names
num_classes = len(class_names)
# Out:
# Found 15515 files belonging to 12 classes.
# Using 12412 files for training.
# Found 15515 files belonging to 12 classes.
# Using 3103 files for validation.

# %% [markdown]
# ### Normalisasi Data

# %%
# menghindari nilai piksel yang besar
normalization_layer = layers.Rescaling(1./255)

# %% [markdown]
# ### Augmentasi Data

# %%
# Melakukan augmentasi data pada dataset training
# Menerapkan normalisasi pada dataset training dan validasi.
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),

])

train_ds = train_ds.map(lambda x, y: (data_augmentation(normalization_layer(x)), y))
val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))

# %% [markdown]
# ### Optimasi dengan Prefetching, caching, shuffling

# %%
# Meningkatkan efisiensi pemrosesan data menggunakan caching, shuffling, dan prefetching
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

for image_batch, labels_batch in train_ds.take(1):
  print("Image batch shape: ", image_batch.shape)
  print("Label batch shape: ", labels_batch.shape)
# Out:
# Image batch shape:  (32, 128, 128, 3)
# Label batch shape:  (32,)

# %% [markdown]
# # Visualisasi Data
#
#   Run kembali untuk melihat output yang lain

# %%
# Menampilkan contoh gambar dari batch data training
for image_batch, label_batch in train_ds.take(1):
  plt.figure(figure=(10, 10))
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy())
    plt.title(int(label_batch[i]))
    plt.axis("off")
  plt.show()

# %% [markdown]
# # Create dan Compile Model

# %%
# Menampilkan jumlah GPU yang tersedia
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# Path ke dataset
dataset_path = '/content/dataset'

# Inisialisasi Dataset Training dan Validasi
train_ds = image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(128, 128),
    batch_size=32
)

val_ds = image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(128, 128),
    batch_size=32
)

# Menentukan Jumlah Kelas
num_classes = len(train_ds.class_names)

# Mendefinisikan Model CNN
def create_model():
    inputs = layers.Input(shape=(128, 128, 3))
    base_model = ResNet50(include_top=False, weights='imagenet', input_tensor=inputs)
    base_model.trainable = False

    x = base_model(inputs)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.4)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs=inputs, outputs=outputs)

    optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9)
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    return model

model = create_model()
model.summary()
# Out:
# Num GPUs Available:  1
# Found 15515 files belonging to 12 classes.
# Using 12412 files for training.
# Found 15515 files belonging to 12 classes.
# Using 3103 files for validation.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ resnet50 (Functional)                │ (None, 4, 4, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 2048)                │           8,192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         524,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 12)                  │           3,084 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 24,123,532 (92.02 MB)
#  Trainable params: 531,724 (2.03 MB)
#  Non-trainable params: 23,591,808 (90.00 MB)

# %% [markdown]
# # Train Model

# %%
# Menampilkan model
model = create_model()

# Aktifkan fine-tuning
base_model = model.layers[1]
base_model.trainable = True
for layer in base_model.layers[:-30]:
    layer.trainable = False

# Re-compile model
optimizer = tf.keras.optimizers.SGD(learning_rate=0.0001, momentum=0.9)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Menentukan Callback
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ModelCheckpoint('/content/best_model.keras', save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-7)
]

# Menentukan Parameter Pelatihan
num_train_samples = 12412
num_val_samples = 3103

batch_size = 32
steps_per_epoch = num_train_samples // batch_size
validation_steps = num_val_samples // batch_size

train_ds = train_ds.repeat()
val_ds = val_ds.repeat()

# Melatih model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    epochs=20,
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 45s 69ms/step - accuracy: 0.3419 - loss: 2.3267 - val_accuracy: 0.7731 - val_loss: 0.7822 - learning_rate: 1.0000e-04
# Epoch 2/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 32s 66ms/step - accuracy: 0.7451 - loss: 0.8344 - val_accuracy: 0.8317 - val_loss: 0.5658 - learning_rate: 1.0000e-04
# Epoch 3/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.8136 - loss: 0.5852 - val_accuracy: 0.8518 - val_loss: 0.4863 - learning_rate: 1.0000e-04
# Epoch 4/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.8490 - loss: 0.4808 - val_accuracy: 0.8688 - val_loss: 0.4280 - learning_rate: 1.0000e-04
# Epoch 5/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.8769 - loss: 0.3929 - val_accuracy: 0.8841 - val_loss: 0.3832 - learning_rate: 1.0000e-04
# Epoch 6/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.9045 - loss: 0.3145 - val_accuracy: 0.8867 - val_loss: 0.3710 - learning_rate: 1.0000e-04
# Epoch 7/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.9104 - loss: 0.2779 - val_accuracy: 0.8935 - val_loss: 0.3480 - learning_rate: 1.0000e-04
# Epoch 8/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.9288 - loss: 0.2361 - val_accuracy: 0.8974 - val_loss: 0.3444 - learning_rate: 1.0000e-04
# Epoch 9/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.9361 - loss: 0.2074 - val_accuracy: 0.9036 - val_loss: 0.3191 - learning_rate: 1.0000e-04
# Epoch 10/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.9416 - loss: 0.1963 - val_accuracy: 0.9010 - val_loss: 0.3211 - learning_rate: 1.0000e-04
# Epoch 11/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.9511 - loss: 0.1658 - val_accuracy: 0.9017 - val_loss: 0.3175 - learning_rate: 1.0000e-04
# Epoch 12/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.9553 - loss: 0.1472 - val_accuracy: 0.9082 - val_loss: 0.3005 - learning_rate: 1.0000e-04
# Epoch 13/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.9604 - loss: 0.1305 - val_accuracy: 0.9046 - val_loss: 0.2986 - learning_rate: 1.0000e-04
# Epoch 14/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.9631 - loss: 0.1224 - val_accuracy: 0.9072 - val_loss: 0.2973 - learning_rate: 1.0000e-04
# Epoch 15/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.9712 - loss: 0.1040 - val_accuracy: 0.9046 - val_loss: 0.3034 - learning_rate: 1.0000e-04
# Epoch 16/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - accuracy: 0.9692 - loss: 0.1005 - val_accuracy: 0.9121 - val_loss: 0.2860 - learning_rate: 1.0000e-04
# Epoch 17/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.9768 - loss: 0.0860 - val_accuracy: 0.9098 - val_loss: 0.2951 - learning_rate: 1.0000e-04
# Epoch 18/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - accuracy: 0.9770 - loss: 0.0798 - val_accuracy: 0.9153 - val_loss: 0.2831 - learning_rate: 1.0000e-04
# Epoch 19/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.9811 - loss: 0.0720 - val_accuracy: 0.9134 - val_loss: 0.2879 - learning_rate: 1.0000e-04
# Epoch 20/20
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.9808 - loss: 0.0694 - val_accuracy: 0.9121 - val_loss: 0.2881 - learning_rate: 1.0000e-04

# %%
# Cetak Akurasi Model
test_loss, test_acc = model.evaluate(val_ds, steps=5000)
print(f"Test accuracy: {test_acc}")
# Out:
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 179s 36ms/step - accuracy: 0.9133 - loss: 0.2875
# Test accuracy: 0.913534939289093

# %% [markdown]
# # Grafik Akurasi Training dan Validasi

# %%
# Memuat data training dan validasi
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# memuat jumlah epoch
epochs = range(len(acc))

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
fig.suptitle('Training and validation accuracy')

for i, (data, label) in enumerate(zip([(acc, val_acc), (loss, val_loss)], ["Accuracy", "Loss"])):
    ax[i].plot(epochs, data[0], 'r', label="Training " + label)
    ax[i].plot(epochs, data[1], 'b', label="Validation " + label)
    ax[i].legend()
    ax[i].set_xlabel('epochs')

plt.show()

# %% [markdown]
# # Save Model ke dalam **TensorFlowjs**

# %%
from tensorflow.keras.models import load_model

model = load_model('/content/best_model.keras')
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ resnet50 (Functional)                │ (None, 4, 4, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 2048)                │           8,192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │         524,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 12)                  │           3,084 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 39,105,434 (149.18 MB)
#  Trainable params: 14,981,900 (57.15 MB)
#  Non-trainable params: 9,141,632 (34.87 MB)
#  Optimizer params: 14,981,902 (57.15 MB)

# %%
model.export('/content/best_model')
# Out:
# Saved artifact at '/content/best_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name='input_layer_2')
# Output Type:
#   TensorSpec(shape=(None, 12), dtype=tf.float32, name=None)
# Captures:
#   135735096672848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096677776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096685872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096687984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096681296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096683584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096682528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096104336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096103632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096109440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096107152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096105744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096112960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096113664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096114544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096852544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096112080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096853424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096860288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096860464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096857296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096858176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096853600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096865040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096862752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096859408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096861696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096862400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096866448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096867504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096807440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096803392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096806032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096812544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096810256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096808848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096815184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096816064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096816416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096819408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096818000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096816592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735093987984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735093991152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735093986752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735093993264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735093991328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735093990624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735093997664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094000304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094001184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094001008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735093999424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094001904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094005776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094006656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094005072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094010880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094008592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094007184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094013520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094014400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094014752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094017744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094016336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094014928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094219472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094220352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094218768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094224576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094222288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094220880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094227216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094228272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094230208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094230736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094229680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094280784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094287296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094287472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094284304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094285184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094283600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094292048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094289760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094286416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094288704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094295744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094293456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094294512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094295040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094365520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094364112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094370624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094368336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094366928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094373264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094374144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094365696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094377488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094376080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094374672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094463120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094460480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094462240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094468224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094465936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094464528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094472272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094473152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094473504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094476496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094475088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094473680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094529360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094530240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094527952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094534464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094532176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094530768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094537104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735098369552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096033872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135736128396752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135736128397104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096034400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735096040384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094536928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094539920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094539392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094540272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094539744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094660608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094661488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094659200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094665712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094663424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094662016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094668352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094669232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094660784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094672576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094671168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094669760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094672752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094726848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094725440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094731952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094729664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094728256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094734592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094735648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094736528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094731600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094737232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094736704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094860208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094860384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094857216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094858096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094855808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094864960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094862672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094859328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094861616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094868656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094866368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094867424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094867952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094922048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094920640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094927152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094924864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094923456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094929792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094930672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094922224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094934896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094932608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094931200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735094934192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735095003264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735095002384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735095008368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735095006080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735095004672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735095012416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735095013296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735095009600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735095016640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735095015232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735095013824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125494592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125491952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125493712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125499696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125497408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125496000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125502336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125503216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125494768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125507440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125505152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125503744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125506736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125577216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125575808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125582320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125580032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125578624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125584960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125585840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125577392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125589184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125587776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125586368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125674816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125672176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125673936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125679920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125677632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125676224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125683968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125685024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125685904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125679568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125686608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125686080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125741056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125741936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125739648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125746160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125743872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125742464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125748800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125749680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125741232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125753024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125751616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125750208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125840064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125836016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125838656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125845168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125842880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125841472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125847808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125848864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125849744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125844816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125850448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125849920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125921280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125922160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125919872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125926384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125924096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125922688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125933776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125931488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125933248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125931840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735125933600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126016768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126020288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126021168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126016416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126025392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126023104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126021696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126031552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126024688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126028032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126029088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126132512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126134272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126131104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126132336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126133040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126137968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126135680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126136736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126142016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126142896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126139200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126146240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126144832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126143424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126166336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126163696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126165456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126171440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126169152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126167744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126174080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126174960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126166512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126179184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126176896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126175488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126178480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126281728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126280320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126286832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126284544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126283136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126289472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126290352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126281904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126293696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126292288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126290880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126379328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126376688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126378448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126384432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126382144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735126380736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735124417120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735124420992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735124418704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735124419760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735124423632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735124423104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735124422224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135735124709216: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
# !tensorflowjs_converter --input_format=tf_saved_model --saved_model_tags=serve /content/best_model /content/model
# Out:
# 2024-11-21 12:27:48.475473: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732192068.496681   27044 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732192068.502974   27044 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 🌲 Try https://ydf.readthedocs.io, the successor of TensorFlow Decision Forests with more features and faster training!
# 2024-11-21 12:27:52.209067: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1732192072.209250   27044 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9713 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1732192074.272326   27044 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732192074.272518   27044 single_machine.cc:361] Starting new session
# I0000 00:00:1732192074.273464   27044 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9713 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5

# %%
# !zip -r /content/model.zip /content/model
# Out:
#   adding: content/model/ (stored 0%)
#   adding: content/model/group1-shard23of23.bin (deflated 7%)
#   adding: content/model/group1-shard13of23.bin (deflated 7%)
#   adding: content/model/group1-shard4of23.bin (deflated 7%)
#   adding: content/model/group1-shard1of23.bin (deflated 7%)
#   adding: content/model/group1-shard10of23.bin (deflated 7%)
#   adding: content/model/group1-shard15of23.bin (deflated 7%)
#   adding: content/model/group1-shard18of23.bin (deflated 7%)
#   adding: content/model/group1-shard3of23.bin (deflated 7%)
#   adding: content/model/group1-shard9of23.bin (deflated 7%)
#   adding: content/model/group1-shard21of23.bin (deflated 7%)
#   adding: content/model/group1-shard2of23.bin (deflated 7%)
#   adding: content/model/group1-shard6of23.bin (deflated 7%)
#   adding: content/model/group1-shard17of23.bin (deflated 7%)
#   adding: content/model/group1-shard14of23.bin (deflated 7%)
#   adding: content/model/group1-shard20of23.bin (deflated 7%)
#   adding: content/model/group1-shard22of23.bin (deflated 7%)
#   adding: content/model/group1-shard5of23.bin (deflated 7%)
#   adding: content/model/group1-shard19of23.bin (deflated 7%)
#   adding: content/model/group1-shard12of23.bin (deflated 7%)
#   adding: content/model/group1-shard7of23.bin (deflated 7%)
#   adding: content/model/group1-shard16of23.bin (deflated 7%)
#   adding: content/model/group1-shard11of23.bin (deflated 7%)
#   adding: content/model/group1-shard8of23.bin (deflated 7%)
#   adding: content/model/model.json (deflated 96%)

# %%
from google.colab import files
files.download('/content/model.zip')
